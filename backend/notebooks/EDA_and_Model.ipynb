# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,RocCurveDisplay

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn modules for pipeline and preprocessing
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# Models
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestClassifier

# Evaluation metrics
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, RocCurveDisplay

# Set visual styles
sns.set_theme(style="whitegrid")
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../data/heart_uci.csv")
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB
#                id         age    trestbps        chol      thalch     oldpeak  \
# ...

# %%
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum().plot(kind="bar")
plt.title("Missing Values Count")
plt.xlabel("Features")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Assuming the data is saved in your working directory
df = pd.read_csv('../data/heart_uci.csv')

# Convert any empty whitespace or specific null strings to standard NaN
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# Create a binary target column
# If 'num' > 0, they have heart disease (1). If 'num' == 0, they do not (0).
df['target'] = (df['num'] > 0).astype(int)

# Drop the original multi-class target to prevent data leakage
df = df.drop(columns=['num'])

print(f"Dataset Shape: {df.shape}")
print(df['target'].value_counts(normalize=True))

# Define features and target
X = df.drop(columns=['target'])
y = df['target']
# Out:
# Dataset Shape: (920, 16)
# target
# 1    0.553261
# 0    0.446739
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("--- Visualizing Distributions and Outliers ---")

# We focus on the continuous numerical columns
numerical_features = ['age', 'trestbps', 'chol', 'thalch', 'oldpeak']

# Create a figure with subplots for each numerical feature
fig, axes = plt.subplots(1, len(numerical_features), figsize=(15, 5))

for i, col in enumerate(numerical_features):
    # Convert to numeric temporarily just for plotting, ignoring errors
    temp_col = pd.to_numeric(df[col], errors='coerce')
    sns.boxplot(y=temp_col, ax=axes[i], color='skyblue', width=0.4)
    axes[i].set_title(col.upper())
    axes[i].set_ylabel('')

plt.tight_layout()
plt.show()

# Note: You will likely see that 'chol' has values at 0.0. 
# Biologically, a cholesterol of 0 is impossible and represents missing data, 
# which our Imputer in the pipeline will handle.
# Out:
# --- Visualizing Distributions and Outliers ---

# %%
from sklearn.ensemble import IsolationForest

print("--- Algorithmic Outlier Detection (Isolation Forest) ---")

# 1. Prepare data for Isolation Forest (Drop NaNs temporarily just for detection)
df_outlier_check = df.copy()

# Force numeric conversion for the algorithm
for col in numerical_features:
    df_outlier_check[col] = pd.to_numeric(df_outlier_check[col], errors='coerce')

# Fill missing values with median specifically for the Isolation Forest to run
df_outlier_check[numerical_features] = df_outlier_check[numerical_features].fillna(df_outlier_check[numerical_features].median())

# 2. Initialize Isolation Forest
# contamination=0.03 means we assume about 3% of our dataset contains extreme anomalies
iso_forest = IsolationForest(n_estimators=100, contamination=0.03, random_state=42)

# 3. Fit and Predict
# Returns 1 for normal, -1 for outlier
outlier_labels = iso_forest.fit_predict(df_outlier_check[numerical_features])

# Add the labels back to the original dataframe
df['is_outlier'] = outlier_labels

# 4. Analyze the Outliers
outliers = df[df['is_outlier'] == -1]
print(f"Total anomalies detected: {len(outliers)} out of {len(df)} patients ({(len(outliers)/len(df))*100:.2f}%)\n")

print("Sample of detected outliers:")
display(outliers[numerical_features + ['target']].head())

# 5. Handle the Outliers
# In a professional setting, we remove the most extreme anomalies to stabilize training
df_clean = df[df['is_outlier'] == 1].drop(columns=['is_outlier'])

print(f"Original dataset size: {df.shape[0]}")
print(f"Cleaned dataset size: {df_clean.shape[0]}")

# Re-assign df to the cleaned version for the rest of the pipeline
df = df_clean.copy()
# Out:
# --- Algorithmic Outlier Detection (Isolation Forest) ---
# Total anomalies detected: 28 out of 920 patients (3.04%)
#
# Sample of detected outliers:
#      age  trestbps   chol  thalch  oldpeak  target
# 3     37     130.0  250.0   187.0      3.5       0
# 91    62     160.0  164.0   145.0      6.2       1
# 121   63     150.0  407.0   154.0      4.0       1
# 126   56     200.0  288.0   133.0      4.0       1
# 132   29     130.0  204.0   202.0      0.0       0
# Original dataset size: 920
# Cleaned dataset size: 892

# %%
print("--- 2. Removing Outliers (IQR) ---")
numerical_features = ['age', 'trestbps', 'chol', 'thalch', 'oldpeak']
initial_rows = df.shape[0]

for col in numerical_features:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    # Keep rows within bounds, or rows with NaNs (to be imputed later)
    df = df[(df[col] >= Q1 - 1.5 * IQR) & (df[col] <= Q3 + 1.5 * IQR) | (df[col].isna())]

print(f"Removed {initial_rows - df.shape[0]} outlier patients. Cleaned shape: {df.shape}")
# Out:
# --- 2. Removing Outliers (IQR) ---
# Removed 195 outlier patients. Cleaned shape: (697, 16)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("--- Visualizing Distributions and Outliers ---")

# We focus on the continuous numerical columns
numerical_features = ['age', 'trestbps', 'chol', 'thalch', 'oldpeak']

# Create a figure with subplots for each numerical feature
fig, axes = plt.subplots(1, len(numerical_features), figsize=(15, 5))

for i, col in enumerate(numerical_features):
    # Convert to numeric temporarily just for plotting, ignoring errors
    temp_col = pd.to_numeric(df[col], errors='coerce')
    sns.boxplot(y=temp_col, ax=axes[i], color='skyblue', width=0.4)
    axes[i].set_title(col.upper())
    axes[i].set_ylabel('')

plt.tight_layout()
plt.show()
# Out:
# --- Visualizing Distributions and Outliers ---

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in df.columns:
    if df[col].dtype=='object':
        df[col]=le.fit_transform(df[col])
numerical_cols = ['age', 'trestbps', 'chol', 'thalch', 'oldpeak']
for col in numerical_cols:
    X[col] = pd.to_numeric(X[col], errors='coerce')
df.head()
# Out:
#    id  age  sex  dataset  cp  trestbps   chol  fbs  restecg  thalch  exang  \
# 0   1   63    1        0   3     145.0  233.0    1        0   150.0      0
# 1   2   67    1        0   0     160.0  286.0    0        0   108.0      1
# 2   3   67    1        0   0     120.0  229.0    0        0   129.0      1
# 4   5   41    0        0   1     130.0  204.0    0        0   172.0      0
# 5   6   56    1        0   1     120.0  236.0    0        1   178.0      0
#
#    oldpeak  slope   ca  thal  target
# 0      2.3      0  0.0     0       0
# 1      1.5      1  3.0     1       1
# 2      2.6      1  2.0     2       1
# 4      1.4      2  0.0     1       0
# 5      0.8      2  0.0     1       0

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
df.hist(figsize=(15, 10), bins=20)
plt.show()

# %%
X=df.drop("target", axis=1)
y=df["target"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2, stratify=y
)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

model = RandomForestClassifier()
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8428571428571429
# Confusion Matrix:
#  [[64 11]
#  [11 54]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85        75
#            1       0.83      0.83      0.83        65
#
#     accuracy                           0.84       140
#    macro avg       0.84      0.84      0.84       140
# weighted avg       0.84      0.84      0.84       140

# %%
fig, ax = plt.subplots(1,1, figsize=(10, 5))

sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues', cbar=False, ax=ax)
ax.set_title('Confusion Matrix')

# plt.tight_layout()
plt.show()

# %%
import joblib
from pathlib import Path

model_path = Path("../models/heart_model.joblib")
joblib.dump(model, model_path)

print("Model saved at:", model_path)
# Out:
# Model saved at: ..\models\heart_model.joblib
